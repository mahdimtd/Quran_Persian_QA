# %%
# !pip install llama-index-core llama-index-readers-file llama-index-llms-ollama llama-index-embeddings-huggingface

# %%
# %pip install llama-index-llms-huggingface
# %pip install llama-index-llms-huggingface-api

# %%
# %pip install llama-index-readers-file

# %%
from IPython.display import display
import ipywidgets as widgets
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, StorageContext, ServiceContext, load_index_from_storage
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.core.node_parser import SimpleFileNodeParser
import warnings
import os
# from neo4j import GraphDatabase
import spacy

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
data1 = '/content/majmaolbayan.txt'

data2 = '/content/alborhan.txt'

# %%
from llama_index.core.node_parser import SentenceSplitter

node_parser = SentenceSplitter(
    chunk_size=512,
    chunk_overlap=100,
)

# %%
from llama_index.core import SimpleDirectoryReader,VectorStoreIndex

documents = SimpleDirectoryReader(input_files=[data1, data2]).load_data()

# %%
# %pip install llama-index-llms-openai

# %%
embed_model = HuggingFaceEmbedding(model_name='PartAI/Tooka-SBERT-V2-Large')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# !pip install chromadb llama-index-vector-stores-chroma llama-index-core
# %pip install llama-index-vector-stores-chroma

# %%
persist_directory = "/content/my_chroma_index"
collection_name = "my_collection"
node_parser = SentenceSplitter(chunk_size=512, chunk_overlap=100)

# %%
import chromadb
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import VectorStoreIndex, StorageContext

# ایجاد کلاینت ChromaDB و مجموعه
chroma_client = chromadb.PersistentClient(path=persist_directory)
chroma_collection = chroma_client.get_or_create_collection(name=collection_name)

# تعریف vector store و context ذخیره‌سازی
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# ایجاد ایندکس از اسناد
index = VectorStoreIndex.from_documents(
    documents,
    storage_context=storage_context,
    embed_model=embed_model
)

# %%
# !zip -r /content/my_chroma_index.zip /content/my_chroma_index
# Out:
#   adding: content/my_chroma_index/ (stored 0%)
#   adding: content/my_chroma_index/chroma.sqlite3 (deflated 64%)
#   adding: content/my_chroma_index/9db07586-8ca0-4824-b604-e4958ffc6ec0/ (stored 0%)
#   adding: content/my_chroma_index/9db07586-8ca0-4824-b604-e4958ffc6ec0/link_lists.bin (deflated 75%)
#   adding: content/my_chroma_index/9db07586-8ca0-4824-b604-e4958ffc6ec0/header.bin (deflated 57%)
#   adding: content/my_chroma_index/9db07586-8ca0-4824-b604-e4958ffc6ec0/data_level0.bin (deflated 8%)
#   adding: content/my_chroma_index/9db07586-8ca0-4824-b604-e4958ffc6ec0/index_metadata.pickle (deflated 44%)
#   adding: content/my_chroma_index/9db07586-8ca0-4824-b604-e4958ffc6ec0/length.bin (deflated 61%)

# %%
from google.colab import files
files.download('/content/my_chroma_index.zip')
